# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="newpassword25"
)

print(mydb)

# https://medium.com/@tattwei46/how-to-use-python-with-mysql-79304bee8753
# https://stackoverflow.com/questions/49194719/authentication-plugin-caching-sha2-password-cannot-be-loaded?utm_medium=organic&utm_source=google_rich_qa&utm_campaign=google_rich_qa

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="newpassword25",
  database="citi_bike"
)

mycursor = mydb.cursor()
sql = "SELECT * FROM cities"
mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Abilene', 115930)
# ('Akron', 217074)
# ('Albany', 93994)
# ('Albuquerque', 448607)
# ('Alexandria', 128283)
# ('Allentown', 106632)
# ('Amarillo', 173627)
# ('Anaheim', 328014)
# ('Anchorage', 260283)
# ('Ann Arbor', 114024)
# ('Arden-Arcade', 92040)
# ('Arlington', 332969)
# ('Arlington', 174838)
# ('Arvada', 102153)
# ('Athens-Clarke County', 101489)
# ('Atlanta', 416474)
# ('Augusta-Richmond County', 199775)
# ('Aurora', 276393)
# ('Aurora', 142990)
# ('Austin', 656562)
# ('Bakersfield', 247057)
# ('Baltimore', 651154)
# ('Baton Rouge', 227818)
# ('Beaumont', 113866)
# ('Bellevue', 109569)
# ('Berkeley', 102743)
# ('Billings', 92988)
# ('Birmingham', 242820)
# ('Boise City', 185787)
# ('Boston', 589141)
# ('Boulder', 91238)
# ('Bridgeport', 139529)
# ('Brockton', 93653)
# ('Brownsville', 139722)
# ('Buffalo', 292648)
# ('Burbank', 100316)
# ('Cambridge', 101355)
# ('Cape Coral', 102286)
# ('Carrollton', 109576)
# ('Carson', 89089)
# ('Cary', 91213)
# ('Cedar Rapids', 120758)
# ...

# %%
myresult
# Out:
# [('Abilene', 115930),
#  ('Akron', 217074),
#  ('Albany', 93994),
#  ('Albuquerque', 448607),
#  ('Alexandria', 128283),
#  ('Allentown', 106632),
#  ('Amarillo', 173627),
#  ('Anaheim', 328014),
#  ('Anchorage', 260283),
#  ('Ann Arbor', 114024),
#  ('Arden-Arcade', 92040),
#  ('Arlington', 332969),
#  ('Arlington', 174838),
#  ('Arvada', 102153),
#  ('Athens-Clarke County', 101489),
#  ('Atlanta', 416474),
#  ('Augusta-Richmond County', 199775),
#  ('Aurora', 276393),
#  ('Aurora', 142990),
#  ('Austin', 656562),
#  ('Bakersfield', 247057),
#  ('Baltimore', 651154),
#  ('Baton Rouge', 227818),
#  ('Beaumont', 113866),
#  ('Bellevue', 109569),
#  ('Berkeley', 102743),
#  ('Billings', 92988),
#  ('Birmingham', 242820),
#  ('Boise City', 185787),
#  ('Boston', 589141),
#  ('Boulder', 91238),
#  ('Bridgeport', 139529),
#  ('Brockton', 93653),
#  ('Brownsville', 139722),
#  ('Buffalo', 292648),
#  ('Burbank', 100316),
#  ('Cambridge', 101355),
#  ('Cape Coral', 102286),
# ...

# %%
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql mssql+pyodbc://root:newpassword25@127.0.0.1:3306/citi_bike?DRIVER={sqlsrv}

# mssql+pyodbc://user:password@server/database?DRIVER={enty in /etc/odbcinst.ini}

# %%
import os
import glob

path = '/Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/scripts/workspace/Link_Michael/test'
extension = 'csv'
os.chdir(path)
result = glob.glob('*.{}'.format(extension))
# print(result)
type(result)
# Out:
# list

# %%
last_header = None
# Loop through the files

files = result

for file in files:
    with open(file) as f:
        # Read the header
        header = f.readline().split(',')
        header = [i.replace(" ", "").replace('"', "").lower() for i in header]
#         header = header.strip(' ').lower()
        print(len(header), '\n', header, '\n')
#         # If this is the first file, then store the
#         # header for later comparison
#         if last_header == None:
#             last_header = header
#         # Check that the header match the last header
#         elif header.strip().lower() != last_header.strip().lower():
#             print(header)
#             quit()
#         print(len(header.strip().lower()))
#         # Read the remaining lines
# #         lines = f.readlines()
# Out:
# 15
#  ['tripduration', 'starttime', 'stoptime', 'startstationid', 'startstationname', 'startstationlatitude', 'startstationlongitude', 'endstationid', 'endstationname', 'endstationlatitude', 'endstationlongitude', 'bikeid', 'usertype', 'birthyear', 'gender\n']
#
# 15
#  ['tripduration', 'starttime', 'stoptime', 'startstationid', 'startstationname', 'startstationlatitude', 'startstationlongitude', 'endstationid', 'endstationname', 'endstationlatitude', 'endstationlongitude', 'bikeid', 'usertype', 'birthyear', 'gender\n']
#
# 15
#  ['tripduration', 'starttime', 'stoptime', 'startstationid', 'startstationname', 'startstationlatitude', 'startstationlongitude', 'endstationid', 'endstationname', 'endstationlatitude', 'endstationlongitude', 'bikeid', 'usertype', 'birthyear', 'gender\n']
#
# 15
# ...

# %% [markdown]
# ### Referencing SQLite data

# %%
# /Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/scripts/workspace/Link_Michael/SQL_SAFI.sqlite
# /Users/michaellink/Desktop/sqlite_practice/test_citi_bike.db
# %load_ext sql
# %sql sqlite:////Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/data/citibike/sqlite/citi_bike.db

# %% [markdown]
# ### Selecting all from the crops table

# %%
# %sql SELECT * FROM yr_2019 LIMIT 5;
# Out:
#  * sqlite:////Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/data/citibike/sqlite/citi_bike.db
# Done.
# [(20, '2019-01-01 00:01:47.4010', '2019-01-01 00:07:07.5810', 3160, 'Central Park West & W 76 St', 40.77896784, -73.97374737, 3283, 'W 89 St & Columbus Ave', 40.7882213, -73.97041561, 15839, 'Subscriber', 1971, 1),
#  (16, '2019-01-01 00:04:43.7360', '2019-01-01 00:10:00.6080', 519, 'Pershing Square North', 40.751873, -73.977706, 518, 'E 39 St & 2 Ave', 40.74780373, -73.9734419, 32723, 'Subscriber', 1964, 1),
#  (91, '2019-01-01 00:06:03.9970', '2019-01-01 00:15:55.4380', 3171, 'Amsterdam Ave & W 82 St', 40.78524672, -73.97667321, 3154, 'E 77 St & 3 Ave', 40.77314236, -73.95856158, 27451, 'Subscriber', 1987, 1),
#  (719, '2019-01-01 00:07:03.5450', '2019-01-01 00:52:22.6500', 504, '1 Ave & E 16 St', 40.73221853, -73.98165557, 3709, 'W 15 St & 6 Ave', 40.738046142482766, -73.99642959237099, 21579, 'Subscriber', 1990, 1),
# ...

# %% [markdown]
# ### Referencing SQLite data

# %%
# /Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/scripts/workspace/Link_Michael/SQL_SAFI.sqlite
# /Users/michaellink/Desktop/sqlite_practice/test_citi_bike.db
# %load_ext sql
# %sql sqlite:////Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/data/citibike/sqlite/citi_bike.db

# %% [markdown]
# ### Selecting all from the crops table

# %%
# %sql SELECT * FROM yr_2019 LIMIT 5;
# Out:
#  * sqlite:////Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/data/citibike/sqlite/citi_bike.db
# Done.
# [(20, '2019-01-01 00:01:47.4010', '2019-01-01 00:07:07.5810', 3160, 'Central Park West & W 76 St', 40.77896784, -73.97374737, 3283, 'W 89 St & Columbus Ave', 40.7882213, -73.97041561, 15839, 'Subscriber', 1971, 1),
#  (16, '2019-01-01 00:04:43.7360', '2019-01-01 00:10:00.6080', 519, 'Pershing Square North', 40.751873, -73.977706, 518, 'E 39 St & 2 Ave', 40.74780373, -73.9734419, 32723, 'Subscriber', 1964, 1),
#  (91, '2019-01-01 00:06:03.9970', '2019-01-01 00:15:55.4380', 3171, 'Amsterdam Ave & W 82 St', 40.78524672, -73.97667321, 3154, 'E 77 St & 3 Ave', 40.77314236, -73.95856158, 27451, 'Subscriber', 1987, 1),
#  (719, '2019-01-01 00:07:03.5450', '2019-01-01 00:52:22.6500', 504, '1 Ave & E 16 St', 40.73221853, -73.98165557, 3709, 'W 15 St & 6 Ave', 40.738046142482766, -73.99642959237099, 21579, 'Subscriber', 1990, 1),
# ...

# %%
# Speed up. This is pretty slow
# %sql select * from yr_2019 order by random() limit 10;
# Out:
#  * sqlite:////Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/data/citibike/sqlite/citi_bike.db
# Done.
# [(224, '2019-11-07 16:30:05.3540', '2019-11-07 16:50:29.4760', 478, '11 Ave & W 41 St', 40.76030096, -73.99884222, 497, 'E 17 St & Broadway', 40.73704984, -73.99009296, 39372, 'Subscriber', 1954, 1),
#  (14, '2019-10-28 14:50:00.4190', '2019-10-28 15:00:15.1460', 3135, 'E 75 St & 3 Ave', 40.77112927, -73.95772297, 3136, '5 Ave & E 63 St', 40.766368, -73.971518, 34239, 'Subscriber', 1955, 1),
#  (43, '2019-08-29 09:07:01.5820', '2019-08-29 09:12:45.5720', 167, 'E 39 St & 3 Ave', 40.7489006, -73.97604882, 526, 'E 33 St & 5 Ave', 40.74765947, -73.98490707, 32869, 'Subscriber', 1994, 2),
#  (79, '2019-03-09 10:24:10.6200', '2019-03-09 10:38:50.3770', 3081, 'Graham Ave & Grand St', 40.711863, -73.944024, 313, 'Washington Ave & Park Ave', 40.69610226, -73.96751037, 37383, 'Subscriber', 1985, 1),
# ...

# %%
import pandas as pd
result = %sql select * from cities;
df = result.DataFrame()
print(type(df))
df
# Out:
#  * sqlite:////Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/data/citibike/sqlite/cb.db
# Done.
# <class 'pandas.core.frame.DataFrame'>
#               name  population
# 0          Abilene      115930
# 1            Akron      217074
# 2           Albany       93994
# 3      Albuquerque      448607
# 4       Alexandria      128283
# ..             ...         ...
# 269        Wichita      344284
# 270  Wichita Falls      104197
# 271  Winston-Salem      185776
# 272      Worcester      172648
# 273        Yonkers      196086
#
# [274 rows x 2 columns]

# %%
# %load_ext sql

# %%
# %sql sqlite://

# %%
# %%sql
# CREATE TABLE EMPLOYEE(firstname varchar(50),lastname varchar(50));
# INSERT INTO EMPLOYEE VALUES('Tom','Mitchell');
# INSERT INTO EMPLOYEE VALUES('Jack','Ryan');

# %%
 # %sql SELECT * from EMPLOYEE;

# %% [markdown]
# ### Referencing SQLite data

# %%
# /Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/scripts/workspace/Link_Michael/SQL_SAFI.sqlite

# %sql sqlite:////Users/michaellink/Desktop/__NYCDSA/_Projects/Capstone/scripts/workspace/Link_Michael/SQL_SAFI.sqlite

# %% [markdown]
# ### Selecting all from the crops table

# %%
# %sql select * from Crops

# %% [markdown]
# ### Specialized query

# %%
# %sql SELECT * from Crops WHERE D_curr_crop = "maize" AND ID <= 3;

# %%
import pandas as pd
result = %sql SELECT * from Crops WHERE D_curr_crop = "maize" AND ID <= 3;
df = result.DataFrame()
print(type(df))
df

# %%
df.info()

# %%
# !conda install -c conda-forge nodejs

# %%
# !pip install jupyterlab_sql

# %%
# !jupyter serverextension enable jupyterlab_sql --py --sys-prefix

# %%
# !jupyter lab build
